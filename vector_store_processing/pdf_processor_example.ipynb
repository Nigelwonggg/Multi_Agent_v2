# %%
import os
from pdf_processor import PDFProcessor
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Define paths (adjust as necessary)
PDF_DIR = "./med_books/"
OUTPUT_PATH = "./data/temp_pdfs_output/"
TEXT_DB_DIR = "med_text_db_test"
IMAGE_DB_DIR = "med_image_db_test"

# %%
# Create an instance of PDFProcessor
processor = PDFProcessor(
    pdf_dir=PDF_DIR,
    output_path=OUTPUT_PATH,
    text_db_directory=TEXT_DB_DIR,
    image_db_directory=IMAGE_DB_DIR,
    domain="medical",
    text_model="llama-3.1-8b-instant",
    vision_model="meta-llama/llama-4-scout-17b-16e-instruct",
    base_url="https://api.groq.com/openai/v1",
    remove_old_db=False
)

# %%
# Category of the PDFs
category = "Neurology"

# Name of the PDF file (only edit if you want to process one PDF)
pdf_filename = "meningioma_001.pdf"

# %%
# Path to the PDF file, if the PDF is not in the PDF_DIR directory please provide the full path
single_pdf_path = os.path.join(PDF_DIR, pdf_filename)

# Print single_pdf_path
print(single_pdf_path)
# Out:
# ./med_books/meningioma_001.pdf

# %%
processor.process_pdf(pdf_file_path=single_pdf_path, category=category)
# Out:
# Processing ./med_books/meningioma_001.pdf
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 processor.process_pdf(pdf_file_path=single_pdf_path, category=category)
#
# File ~/Public/LLM_Learning/EDU_LLM/refactor_full_app/vector_store_processing/pdf_processor.py:332, in PDFProcessor.process_pdf(self, pdf_file_path, category)
#     327 print(f"Processing {pdf_file_path}")
#     329 # Use the file previous directory as the category
#     330 # category = os.path.basename(os.path.normpath(pdf_file_path))
# --> 332 chunks = self.chunk_pdf(pdf_file_path)
#     334 # Process image chunks
#     335 images = self.get_image_chunks(chunks)
#
# File ~/Public/LLM_Learning/EDU_LLM/refactor_full_app/vector_store_processing/pdf_processor.py:152, in PDFProcessor.chunk_pdf(self, pdf_file)
#     148 def chunk_pdf(self, pdf_file):
#     149     """
# ...
